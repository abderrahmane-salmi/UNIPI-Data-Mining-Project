# %% [markdown]
# # Density Based Clustering

# %% [markdown]
# **Authors:** Abderrahmane Salmi, Ricardo Talarico, Lorenzo Allegrini

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
tracks_df = pd.read_csv("../datasets/tracks_cleaned.csv")
artists_df = pd.read_csv("../datasets/artists_cleaned.csv")

# %% [markdown]
# ## Features Selection

# %%
selected_features = [
    # linguistic / lyrics
    # 'n_tokens',
    # 'swear_IT',
    # 'lexical_density',

    # audio features
    # 'bpm',
    'centroid',
    'loudness',
    'spectral_complexity',
    # 'flux',
    'rolloff',

    # popularity
    'popularity',
    # 'relative_popularity',

    # time-related
    # 'season_autumn', 'season_spring', 'season_summer', 'season_winter',

    # engineered features
    # 'has_collaboration',
    'aggressiveness',
    # 'song_age',
    # 'duration_sec'
]

# %%
#Extract feature matrix
X = tracks_df[selected_features].copy()

# %% [markdown]
# ## Preprocessing (Scaling & Normalization)

# %%
# Check for NaN values
print(X.isna().sum())
# Out:
# centroid               0
# loudness               0
# spectral_complexity    0
# rolloff                0
# popularity             0
# aggressiveness         0
# dtype: int64

# %% [markdown]
# **log1p transformation**: applying log to numeric skewed features

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select numeric features for clustering
numeric_features = X.columns.tolist()  # X is our selected features for clustering

# Step 0: Filter out binary and one-hot encoded features (only keep features with >2 unique values)
continuous_features = [col for col in numeric_features if X[col].nunique() > 2]

# Step 1: Compute skewness
skewness = X[continuous_features].skew().sort_values(ascending=False)
print("Skewness of continuous features:\n", skewness)

# Step 2: Plot distribution of highly skewed features (optional)
high_skew = skewness[skewness > 2].index  # threshold for positive skew
# for col in high_skew:
#     plt.figure()
#     sns.histplot(X[col], kde=True)
#     plt.title(f'Distribution of {col} (skew={skewness[col]:.2f})')
#     plt.show()

# Step 3: Apply log1p transformation to highly skewed continuous features
for col in high_skew:
    # Only apply if all values are >= 0 (log1p cannot handle negative values)
    if (X[col] >= 0).all():
        X[col] = np.log1p(X[col])
    else:
        print(f"Skipping {col} because it has negative values.")

# Step 4: Verify the new skewness
new_skewness = X[continuous_features].skew().sort_values(ascending=False)
print("Skewness after log1p transformation:\n", new_skewness)
# Out:
# Skewness of continuous features:
#  popularity             0.260412
# centroid               0.181541
# spectral_complexity    0.099082
# aggressiveness        -0.053941
# rolloff               -0.060360
# loudness              -0.153119
# dtype: float64
# Skewness after log1p transformation:
#  popularity             0.260412
# centroid               0.181541
# spectral_complexity    0.099082
# aggressiveness        -0.053941
# rolloff               -0.060360
# loudness              -0.153119
# dtype: float64

# %% [markdown]
# **Normalization**: We tried to normalize using both z-score and min-max, to see which one works best for different algorithms.

# %%
# Scale the features (z-score)
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
X_zscore = std_scaler.fit_transform(X)

# %%
# Scale the features (Min-Max)
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()
X_minmax = minmax_scaler.fit_transform(X)

# %%
X_scaled = X_minmax

# %% [markdown]
# ## DBScan

# %% [markdown]
# ### Study of Clustering Parameters

# %% [markdown]
# In DBSCAN, we have to choose two parameters:
#
# * **eps:** The maximum distance between two samples for one to be considered as in the neighborhood of the other.
#
# * **min_samples:** The number of samples (or total weight) in a neighborhood for a point to be considered as a core point.
#
# We can find the best parameters for the DBSCAN by using the silhouette score, which is a measure of how similar an object is to its own cluster compared to other clusters, and it ranges from -1 to 1.
#
# We thought of doing a grid search for the parameters by computing the silhouette score for different comibnations of parameters and then choose the combination that gave the best score.
#
# So the first thing to do now is to find the search ranges for each parameter that we'll use for the grid search.

# %% [markdown]
# To find a good range of values for eps, we first plot a graph of the distance to the nearest neighbor of each point (sorted by distance). Then we look for a spot in the graph where the distances suddenly increase. This point is called the knee or elbow, and it gives us a good estimate for eps. This is known as the knee method.

# %%
# 1. Select min_samples
min_samples = 2 * len(selected_features)  # Default value: 2*D

# 2. Calculate distance to the kth nearest neighbor
neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)

# 3. Sort distances (we only care about the distance to the min_samples-th neighbor)
distances = np.sort(distances[:, min_samples-1], axis=0)

# 4. Plot the k-distance Graph
plt.figure(figsize=(10, 6))
plt.plot(distances)
plt.title(f'K-Distance Graph (min_samples={min_samples})')
plt.xlabel('Data Points sorted by distance')
plt.ylabel(f'Epsilon distance to {min_samples}th neighbor')
plt.grid(True)
plt.show()

# %% [markdown]
# These are util functions that automatically generate value ranges for both parameters. This are completely optional, we could've done this step manually by hard-coding the range values in the source code, but we wanted to make it automatically generated to be able to test many values quickly to determin the best ranges.

# %%
def generate_min_samples_range(D, num_values):
    """
    Generates a range of min_samples values centered around 2*D.
    D: Number of dimensions (features).
    num_values: The desired total number of values in the output list.
    """
    # Heuristic center point
    center = 2 * D
    
    # Calculate the span (e.g. 5 steps above and below the center)
    span = max(D // 2, 5) 
    
    start = max(5, center - span) # min_samples should be >= 5
    end = center + span + 1
    
    # Generate num_values points evenly spaced within [start, end]
    min_samples_range = np.linspace(start, end, num_values, dtype=int)
    
    # Ensure all generated values are unique and greater than 5
    return np.unique(min_samples_range[min_samples_range >= 5]).tolist()

# %% [markdown]
# Now we will generate the value ranges for both parameters, for min samples, we used the 2*D as a heuristic, so the range values are centered around it, and for the eps, we used the knee method to read the knee value and use it as a heuristic to determin the range of possible eps values.

# %%
min_samples_range = generate_min_samples_range(len(selected_features), 7)
eps_range = np.round(np.linspace(0.17, 0.25, 9), 2).tolist()
print("Parameters for the grid search:\nmin_samples: {0}\neps: {1}".format(min_samples_range, eps_range))
# Out:
# Parameters for the grid search:
# min_samples: [7, 8, 10, 12, 14, 16, 18]
# eps: [0.17, 0.18, 0.19, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25]

# %% [markdown]
# **Grid Search:**

# %%
results = []

print(f"Starting Grid Search with {len(eps_range) * len(min_samples_range)} combinations...")

for eps in eps_range:
    for min_samples in min_samples_range:
        
        # Run DBSCAN
        db = DBSCAN(eps=eps, min_samples=min_samples)
        labels = db.fit_predict(X_scaled)
        
        # Count clusters (ignoring noise which is -1)
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise = list(labels).count(-1)
        noise_ratio = n_noise / len(labels)

        print(f"eps={eps}, min_samples={min_samples}, "
        f"clusters={n_clusters}, noise_ratio={noise_ratio:.2f}")
        
        # We only care if we found at least 2 clusters and not everything is noise
        if n_clusters > 1 and noise_ratio < 0.9:
            # Calculate Silhouette Score
            sil_score = silhouette_score(X_scaled, labels)
            
            results.append({
                'eps': eps,
                'min_samples': min_samples,
                'n_clusters': n_clusters,
                'noise_ratio': noise_ratio,
                'silhouette': sil_score
            })
            
# Create a DataFrame of results
results_df = pd.DataFrame(results)
# Out:
# Starting Grid Search with 63 combinations...
# eps=0.17, min_samples=7, clusters=1, noise_ratio=0.03
# eps=0.17, min_samples=8, clusters=1, noise_ratio=0.04
# eps=0.17, min_samples=10, clusters=1, noise_ratio=0.04
# eps=0.17, min_samples=12, clusters=1, noise_ratio=0.05
# eps=0.17, min_samples=14, clusters=1, noise_ratio=0.05
# eps=0.17, min_samples=16, clusters=1, noise_ratio=0.06
# eps=0.17, min_samples=18, clusters=1, noise_ratio=0.07
# eps=0.18, min_samples=7, clusters=1, noise_ratio=0.02
# eps=0.18, min_samples=8, clusters=1, noise_ratio=0.02
# eps=0.18, min_samples=10, clusters=1, noise_ratio=0.03
# eps=0.18, min_samples=12, clusters=1, noise_ratio=0.03
# eps=0.18, min_samples=14, clusters=1, noise_ratio=0.04
# eps=0.18, min_samples=16, clusters=1, noise_ratio=0.04
# eps=0.18, min_samples=18, clusters=1, noise_ratio=0.04
# eps=0.19, min_samples=7, clusters=1, noise_ratio=0.01
# eps=0.19, min_samples=8, clusters=1, noise_ratio=0.01
# eps=0.19, min_samples=10, clusters=1, noise_ratio=0.02
# eps=0.19, min_samples=12, clusters=1, noise_ratio=0.02
# eps=0.19, min_samples=14, clusters=1, noise_ratio=0.02
# eps=0.19, min_samples=16, clusters=1, noise_ratio=0.02
# eps=0.19, min_samples=18, clusters=1, noise_ratio=0.03
# eps=0.2, min_samples=7, clusters=1, noise_ratio=0.01
# eps=0.2, min_samples=8, clusters=1, noise_ratio=0.01
# eps=0.2, min_samples=10, clusters=1, noise_ratio=0.01
# eps=0.2, min_samples=12, clusters=1, noise_ratio=0.01
# eps=0.2, min_samples=14, clusters=1, noise_ratio=0.02
# eps=0.2, min_samples=16, clusters=1, noise_ratio=0.02
# eps=0.2, min_samples=18, clusters=1, noise_ratio=0.02
# eps=0.21, min_samples=7, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=8, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=10, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=12, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=14, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=16, clusters=1, noise_ratio=0.01
# eps=0.21, min_samples=18, clusters=1, noise_ratio=0.01
# eps=0.22, min_samples=7, clusters=1, noise_ratio=0.00
# eps=0.22, min_samples=8, clusters=1, noise_ratio=0.00
# eps=0.22, min_samples=10, clusters=1, noise_ratio=0.00
# eps=0.22, min_samples=12, clusters=1, noise_ratio=0.00
# eps=0.22, min_samples=14, clusters=1, noise_ratio=0.01
# eps=0.22, min_samples=16, clusters=1, noise_ratio=0.01
# eps=0.22, min_samples=18, clusters=1, noise_ratio=0.01
# eps=0.23, min_samples=7, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=8, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=10, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=12, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=14, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=16, clusters=1, noise_ratio=0.00
# eps=0.23, min_samples=18, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=7, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=8, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=10, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=12, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=14, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=16, clusters=1, noise_ratio=0.00
# eps=0.24, min_samples=18, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=7, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=8, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=10, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=12, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=14, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=16, clusters=1, noise_ratio=0.00
# eps=0.25, min_samples=18, clusters=1, noise_ratio=0.00

# %%
grid_search_results = results_df.copy()

# %%
# Sort by best Silhouette Score
print("Top 5 Parameter Combinations:")
print(grid_search_results.sort_values(by='silhouette', ascending=False).head(5))
# print(grid_search_results.columns)
# Out:
# Top 5 Parameter Combinations:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13052\3234565484.py in ?()
#       1 # Sort by best Silhouette Score
#       2 print("Top 5 Parameter Combinations:")
# ----> 3 print(grid_search_results.sort_values(by='silhouette', ascending=False).head(5))
#       4 # print(grid_search_results.columns)
#
# c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'silhouette'

# %% [markdown]
# Heatmap Visualization of the grid search results

# %%
# Pivot table for the heatmap
results_tmp = grid_search_results.copy()
pivot_table = results_tmp.pivot(index='min_samples', columns='eps', values='silhouette')

plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, annot=True, cmap='viridis', fmt=".2f")
plt.title('DBSCAN Silhouette Score for Parameter Combinations')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Pivot table for the heatmap
#       2 results_tmp = grid_search_results.copy()
# ----> 3 pivot_table = results_tmp.pivot(index='min_samples', columns='eps', values='silhouette')
#       5 plt.figure(figsize=(12, 6))
#       6 sns.heatmap(pivot_table, annot=True, cmap='viridis', fmt=".2f")
#
# File c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\pivot.py:553, in pivot(data, columns, index, values)
#     549         index_list = [
#     550             data._constructor_sliced(data.index, name=data.index.name)
#     551         ]
#     552 else:
# --> 553     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     555 data_columns = [data[col] for col in columns_listlike]
#     556 index_list.extend(data_columns)
#
# File c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\Abdou\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'min_samples'

# %%
# # 2 heatmaps, one for cluster numbers, and one for silhouette score

# results_tmp = grid_search_results.copy()

# # Pivot tables for heatmaps
# df_clusters_grid = results_tmp.pivot(index='eps', columns='min_samples', values='n_clusters')
# df_sil_grid      = results_tmp.pivot(index='eps', columns='min_samples', values='silhouette')

# # Convert cluster grid to integers (silhouette stays float)
# df_clusters_grid_int = df_clusters_grid.fillna(0).astype(int)

# fig, axs = plt.subplots(1, 2, figsize=(22, 8))

# # --- Heatmap 1: Number of Clusters ---
# sns.heatmap(
#     df_clusters_grid_int,
#     annot=True,
#     fmt="d",
#     cmap="coolwarm",
#     cbar=False,
#     ax=axs[0]
# )
# axs[0].set_title("Number of Clusters")
# axs[0].set_xlabel("min_samples")
# axs[0].set_ylabel("epsilon")

# # --- Heatmap 2: Silhouette Score ---
# sns.heatmap(
#     df_sil_grid,
#     annot=True,
#     fmt=".3f",
#     cmap="coolwarm",
#     cbar=False,
#     ax=axs[1]
# )
# axs[1].set_title("Silhouette Score")
# axs[1].set_xlabel("min_samples")
# axs[1].set_ylabel("epsilon")

# plt.tight_layout()
# plt.show()

# %% [markdown]
# Best possible combination

# %%
# Filter results to only those with at least 2 clusters
valid_results = grid_search_results[grid_search_results['n_clusters'] >= 2]

if valid_results.empty:
    print("No valid parameter combinations found with n_clusters >= 2.")
else:
    # Pick combination with highest silhouette score
    best_result = valid_results.sort_values(by='silhouette', ascending=False).iloc[0]

    print("\nBest Parameters Found (n_clusters > 2):")
    print(f"eps = {best_result['eps']}")
    print(f"min_samples = {best_result['min_samples']}")
    print(f"n_clusters = {best_result['n_clusters']}")
    print(f"noise_ratio = {best_result['noise_ratio']:.2%}")
    print(f"silhouette_score = {best_result['silhouette']:.4f}")
# Out:
# Best Parameters Found (n_clusters > 2):
# eps = 0.26
# min_samples = 13.0
# n_clusters = 2.0
# noise_ratio = 0.20%
# silhouette_score = 0.4831

# %%
# Extract best parameters
best_eps = float(best_result['eps'])
best_min_samples = int(best_result['min_samples'])

# %% [markdown]
# Validate the best parameters using K-distance graph and knee method

# %%
# 1. Use best_min_samples
k = best_min_samples

# 2. Compute k-nearest neighbor distances
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(X_scaled)
distances, _ = neighbors_fit.kneighbors(X_scaled)

# 3. Sort distances to the k-th nearest neighbor
k_distances = np.sort(distances[:, k - 1])

# 4. Plot k-distance graph
plt.figure(figsize=(10, 6))
plt.plot(k_distances, label=f'{k}-NN distance')
plt.axhline(
    y=best_eps,
    color='red',
    linestyle='--',
    linewidth=2,
    label=f'Chosen eps = {best_eps:.3f}'
)

plt.title(f'K-Distance Graph (min_samples = {k})')
plt.xlabel('Data points (sorted)')
plt.ylabel(f'Distance to {k}th nearest neighbor')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **DBSCAN Algorithm:** Now we can run the algorithm using the best found parameters

# %%
# RUN DBSCAN
dbscan = DBSCAN(eps=best_eps, min_samples=best_min_samples)
labels = dbscan.fit_predict(X_scaled)

# Add labels to dataframe
X['dbscan_cluster'] = labels

# Count clusters
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# Compute silhouette score
silhouette = silhouette_score(X_scaled, labels)

# Print results
print(f'DBSCAN (eps={best_eps}, min_samples={best_min_samples})')
print(f'Number of labels: {len(set(labels))}')
print(f'Number of clusters: {n_clusters_}')
print(f'Number of noise points: {n_noise_}')
print(f'Noise ratio: {n_noise_ / len(labels):.2%}')
print(f'Silhouette score: {silhouette:.4f}')

# Print count of each label
print("\nCounts per label:")
print(pd.Series(labels).value_counts().sort_index())
# Out:
# DBSCAN (eps=0.26, min_samples=13)
# Number of labels: 3
# Number of clusters: 2
# Number of noise points: 21
# Noise ratio: 0.20%
# Silhouette score: 0.4831
#
# Counts per label:
# -1      21
#  0    3347
#  1    6904
# Name: count, dtype: int64

# %% [markdown]
# ## Characterization and interpretation of the clusters

# %%
# Reduce dimensions for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a temporary dataframe for plotting
plot_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
plot_df['Cluster'] = labels

plt.figure(figsize=(12, 8))
# Plot Noise (Cluster -1) in Grey/Black and smaller
sns.scatterplot(
    x='PC1', y='PC2', 
    data=plot_df[plot_df['Cluster'] == -1], 
    color='lightgrey', label='Noise', alpha=0.5, s=20
)
# Plot Clusters in Color
sns.scatterplot(
    x='PC1', y='PC2', 
    data=plot_df[plot_df['Cluster'] != -1], 
    hue='Cluster', palette='viridis', s=50
)
plt.title(f'DBSCAN Clustering (eps={best_eps}, min_samples={best_min_samples})')
plt.legend()
plt.show()

# %%
X_tmp = X.copy()

# %%
# Group by cluster and calculate mean of features
cluster_profile = X.groupby('dbscan_cluster').mean()

# We usually check how they deviate from the global mean (Z-scores for interpretation)
global_mean = X.mean()
global_std = X.std()

# Calculate Z-score of the cluster centers relative to the whole dataset
cluster_profile_z = (cluster_profile - global_mean) / global_std

# Plot Heatmap of Feature Importance
plt.figure(figsize=(12, 6))
sns.heatmap(cluster_profile_z.T, cmap='coolwarm', center=0, annot=True)
plt.title('Cluster Characterization (Z-Scores of Feature Means)')
plt.xlabel('Cluster Label (-1 is Noise)')
plt.show()

# %% [markdown]
# Compute cluster counts

# %%
# Compute cluster counts
cluster_counts = X['dbscan_cluster'].value_counts().sort_index()

# Labels (highlight noise clearly)
labels = [
    f"Noise (-1)" if c == -1 else f"Cluster {c}"
    for c in cluster_counts.index
]

print(cluster_counts)

# Plot pie chart
plt.figure(figsize=(7, 7))
plt.pie(
    cluster_counts,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    counterclock=False
)

plt.title("DBSCAN Cluster Distribution")
plt.show()
# Out:
# dbscan_cluster
# -1      21
#  0    3347
#  1    6904
# Name: count, dtype: int64

# %% [markdown]
# Calculate the mean for each feature by cluster label

# %%
cluster_profiles_raw = X.groupby('dbscan_cluster').mean()

print("DBSCAN Cluster Profiles (Raw Feature Means):")
print(cluster_profiles_raw)
# Out:
# DBSCAN Cluster Profiles (Raw Feature Means):
#                 centroid   loudness  spectral_complexity   rolloff  \
# dbscan_cluster
# -1              0.132219  24.516210            21.922771  5.953149
#  0              0.142238  25.850132            28.985537  6.326258
#  1              0.137360  24.202620            27.563461  6.264826
#
#                 popularity  has_collaboration  aggressiveness
# dbscan_cluster
# -1               54.523810           0.714286       -0.074186
#  0               33.512997           1.000000        0.123124
#  1               32.623841           0.000000       -0.003567
